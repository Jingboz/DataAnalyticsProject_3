# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
import pandas as pd
from config import api_key
from pprint import pprint

# %%
# Save config information.
url = "https://demo.openweathermap.org/energy/1.0/solar/data?"

# Build partial query URL
query_url = f"{url}appid={api_key}&date=2023-03-30"

# %%
coordi = [["Perth",-31.9523,115.8613],["Karratha",-20.7337,116.8447]]
# set up lists to hold reponse info
city_solar = []

# Loop through the list of cities and perform a request for data on each
for city in coordi:
    response = requests.get(f"{query_url}&lat={city[1]}+&lon=+{city[2]}").json()
    response["city"] = city[0]
    city_solar.append(response)
pprint(city_solar)
# Out:
# [{'city': 'Perth',
#   'date': '2023-03-30',
#   'irradiance': {'daily': [{'clear_sky': {'dhi': 1052.6,
#                                           'dni': 8525.95,
#                                           'ghi': 6021.35},
#                             'cloudy_sky': {'dhi': 1287.78,
#                                            'dni': 6154.28,
#                                            'ghi': 5338.85}}],
#                  'hourly': [{'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'hour': 0},
#                             {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'hour': 1},
#                             {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'hour': 2},
#                             {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'hour': 3},
#                             {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'hour': 4},
#                             {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'hour': 5},
#                             {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'hour': 6},
#                             {'clear_sky': {'dhi': 4.34,
#                                            'dni': 5.26,
#                                            'ghi': 0.76},
#                              'cloudy_sky': {'dhi': 0.29,
#                                             'dni': 0.0,
#                                             'ghi': 0.29},
#                              'hour': 7},
#                             {'clear_sky': {'dhi': 60.41,
#                                            'dni': 542.02,
#                                            'ghi': 170.21},
#                              'cloudy_sky': {'dhi': 80.04,
#                                             'dni': 94.85,
#                                             'ghi': 100.67},
#                              'hour': 8},
#                             {'clear_sky': {'dhi': 86.03,
#                                            'dni': 732.85,
#                                            'ghi': 385.81},
#                              'cloudy_sky': {'dhi': 78.89,
#                                             'dni': 733.12,
#                                             'ghi': 385.75},
#                              'hour': 9},
#                             {'clear_sky': {'dhi': 101.95,
#                                            'dni': 828.98,
#                                            'ghi': 582.83},
#                              'cloudy_sky': {'dhi': 93.56,
#                                             'dni': 830.4,
#                                             'ghi': 582.07},
#                              'hour': 10},
#                             {'clear_sky': {'dhi': 111.92,
#                                            'dni': 882.09,
#                                            'ghi': 736.08},
#                              'cloudy_sky': {'dhi': 120.01,
#                                             'dni': 860.51,
#                                             'ghi': 735.97},
#                              'hour': 11},
#                             {'clear_sky': {'dhi': 117.29,
#                                            'dni': 908.85,
#                                            'ghi': 829.69},
#                              'cloudy_sky': {'dhi': 119.99,
#                                             'dni': 895.7,
#                                             'ghi': 829.65},
#                              'hour': 12},
#                             {'clear_sky': {'dhi': 118.63,
#                                            'dni': 915.46,
#                                            'ghi': 854.66},
#                              'cloudy_sky': {'dhi': 127.84,
#                                             'dni': 892.18,
#                                             'ghi': 852.76},
#                              'hour': 13},
#                             {'clear_sky': {'dhi': 116.07,
#                                            'dni': 903.25,
#                                            'ghi': 808.64},
#                              'cloudy_sky': {'dhi': 128.68,
#                                             'dni': 862.85,
#                                             'ghi': 797.49},
#                              'hour': 14},
#                             {'clear_sky': {'dhi': 109.39,
#                                            'dni': 869.64,
#                                            'ghi': 695.91},
#                              'cloudy_sky': {'dhi': 191.24,
#                                             'dni': 370.38,
#                                             'ghi': 443.86},
#                              'hour': 15},
#                             {'clear_sky': {'dhi': 97.84,
#                                            'dni': 806.22,
#                                            'ghi': 527.49},
#                              'cloudy_sky': {'dhi': 170.37,
#                                             'dni': 318.34,
#                                             'ghi': 342.27},
#                              'hour': 16},
#                             {'clear_sky': {'dhi': 79.61,
#                                            'dni': 690.19,
#                                            'ghi': 321.5},
#                              'cloudy_sky': {'dhi': 128.08,
#                                             'dni': 222.77,
#                                             'ghi': 208.13},
#                              'hour': 17},
#                             {'clear_sky': {'dhi': 49.12,
#                                            'dni': 441.14,
#                                            'ghi': 107.78},
#                              'cloudy_sky': {'dhi': 48.78,
#                                             'dni': 73.17,
#                                             'ghi': 59.93},
#                              'hour': 18},
#                             {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'hour': 19},
#                             {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'hour': 20},
#                             {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'hour': 21},
#                             {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'hour': 22},
#                             {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'hour': 23}]},
#   'lat': -31.9523,
#   'lon': 115.8613,
#   'sunrise': '2023-03-30T06:25:57',
#   'sunset': '2023-03-30T18:15:55',
#   'tz': '+08:00'},
#  {'city': 'Karratha',
#   'date': '2023-03-30',
#   'irradiance': {'daily': [{'clear_sky': {'dhi': 1130.13,
#                                           'dni': 8998.35,
#                                           'ghi': 6953.18},
#                             'cloudy_sky': {'dhi': 1680.3,
#                                            'dni': 2600.33,
#                                            'ghi': 3136.51}}],
#                  'hourly': [{'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'hour': 0},
#                             {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'hour': 1},
#                             {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'hour': 2},
#                             {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'hour': 3},
#                             {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'hour': 4},
#                             {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'hour': 5},
#                             {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'hour': 6},
#                             {'clear_sky': {'dhi': 17.23,
#                                            'dni': 104.67,
#                                            'ghi': 12.02},
#                              'cloudy_sky': {'dhi': 3.13,
#                                             'dni': 0.0,
#                                             'ghi': 3.13},
#                              'hour': 7},
#                             {'clear_sky': {'dhi': 68.1,
#                                            'dni': 604.63,
#                                            'ghi': 223.3},
#                              'cloudy_sky': {'dhi': 57.68,
#                                             'dni': 0.0,
#                                             'ghi': 57.68},
#                              'hour': 8},
#                             {'clear_sky': {'dhi': 93.11,
#                                            'dni': 777.22,
#                                            'ghi': 466.39},
#                              'cloudy_sky': {'dhi': 117.44,
#                                             'dni': 0.0,
#                                             'ghi': 117.44},
#                              'hour': 9},
#                             {'clear_sky': {'dhi': 108.8,
#                                            'dni': 865.65,
#                                            'ghi': 684.79},
#                              'cloudy_sky': {'dhi': 170.52,
#                                             'dni': 3.76,
#                                             'ghi': 173.05},
#                              'hour': 10},
#                             {'clear_sky': {'dhi': 118.59,
#                                            'dni': 914.6,
#                                            'ghi': 852.29},
#                              'cloudy_sky': {'dhi': 210.08,
#                                             'dni': 6.53,
#                                             'ghi': 215.38},
#                              'hour': 11},
#                             {'clear_sky': {'dhi': 123.78,
#                                            'dni': 938.89,
#                                            'ghi': 952.1},
#                              'cloudy_sky': {'dhi': 231.96,
#                                             'dni': 8.73,
#                                             'ghi': 239.74},
#                              'hour': 12},
#                             {'clear_sky': {'dhi': 124.89,
#                                            'dni': 944.05,
#                                            'ghi': 974.85},
#                              'cloudy_sky': {'dhi': 258.13,
#                                             'dni': 11.55,
#                                             'ghi': 268.63},
#                              'hour': 13},
#                             {'clear_sky': {'dhi': 122.04,
#                                            'dni': 931.14,
#                                            'ghi': 918.44},
#                              'cloudy_sky': {'dhi': 261.45,
#                                             'dni': 13.99,
#                                             'ghi': 273.53},
#                              'hour': 14},
#                             {'clear_sky': {'dhi': 114.95,
#                                            'dni': 897.4,
#                                            'ghi': 788.06},
#                              'cloudy_sky': {'dhi': 125.52,
#                                             'dni': 828.88,
#                                             'ghi': 754.16},
#                              'hour': 15},
#                             {'clear_sky': {'dhi': 102.86,
#                                            'dni': 834.27,
#                                            'ghi': 596.17},
#                              'cloudy_sky': {'dhi': 87.96,
#                                             'dni': 798.88,
#                                             'ghi': 566.92},
#                              'hour': 16},
#                             {'clear_sky': {'dhi': 83.84,
#                                            'dni': 718.7,
#                                            'ghi': 363.09},
#                              'cloudy_sky': {'dhi': 82.13,
#                                             'dni': 669.13,
#                                             'ghi': 348.73},
#                              'hour': 17},
#                             {'clear_sky': {'dhi': 51.93,
#                                            'dni': 467.14,
#                                            'ghi': 121.69},
#                              'cloudy_sky': {'dhi': 74.28,
#                                             'dni': 258.88,
#                                             'ghi': 118.11},
#                              'hour': 18},
#                             {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'hour': 19},
#                             {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'hour': 20},
#                             {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'hour': 21},
#                             {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'hour': 22},
#                             {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                              'hour': 23}]},
#   'lat': -20.7337,
#   'lon': 116.8447,
#   'sunrise': '2023-03-30T06:18:54',
#   'sunset': '2023-03-30T18:15:17',
#   'tz': '+08:00'}]

# %%
import json

# %%
with open("./output/output.json", "w") as outfile:
    json.dump(city_solar, outfile)

# %%
from pymongo import MongoClient
import requests

# %% [markdown]
# mongoimport --type json -d Project3 -c solar_city --drop --jsonArray output.json

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['Project3', 'admin', 'classDB', 'config', 'epa', 'local', 'uk_food']

# %%
city_db = mongo['Project3']
print(city_db.list_collection_names())
# Out:
# ['solar_city']

# %%
solar_c = city_db["solar_city"]

# %%
pprint(solar_c.find_one({"city":'Karratha'}))
# Out:
# {'_id': ObjectId('642aaa6f3161af104e9002a9'),
#  'city': 'Karratha',
#  'date': '2023-03-30',
#  'irradiance': {'daily': [{'clear_sky': {'dhi': 1189.78,
#                                          'dni': 9415.65,
#                                          'ghi': 7562.22},
#                            'cloudy_sky': {'dhi': 2508.33,
#                                           'dni': 659.85,
#                                           'ghi': 3029.83}}],
#                 'hourly': [{'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                             'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                             'hour': 0},
#                            {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                             'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                             'hour': 1},
#                            {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                             'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                             'hour': 2},
#                            {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                             'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                             'hour': 3},
#                            {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                             'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                             'hour': 4},
#                            {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                             'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                             'hour': 5},
#                            {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                             'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                             'hour': 6},
#                            {'clear_sky': {'dhi': 31.13,
#                                           'dni': 255.34,
#                                           'ghi': 40.51},
#                             'cloudy_sky': {'dhi': 10.13,
#                                            'dni': 0.0,
#                                            'ghi': 10.13},
#                             'hour': 7},
#                            {'clear_sky': {'dhi': 74.06,
#                                           'dni': 648.31,
#                                           'ghi': 269.95},
#                             'cloudy_sky': {'dhi': 67.49,
#                                            'dni': 0.0,
#                                            'ghi': 67.49},
#                             'hour': 8},
#                            {'clear_sky': {'dhi': 97.34,
#                                           'dni': 800.86,
#                                           'ghi': 517.61},
#                             'cloudy_sky': {'dhi': 173.3,
#                                            'dni': 44.27,
#                                            'ghi': 196.88},
#                             'hour': 9},
#                            {'clear_sky': {'dhi': 112.29,
#                                           'dni': 882.08,
#                                           'ghi': 738.34},
#                             'cloudy_sky': {'dhi': 181.04,
#                                            'dni': 45.47,
#                                            'ghi': 213.7},
#                             'hour': 10},
#                            {'clear_sky': {'dhi': 121.73,
#                                           'dni': 927.8,
#                                           'ghi': 907.22},
#                             'cloudy_sky': {'dhi': 230.79,
#                                            'dni': 37.89,
#                                            'ghi': 263.22},
#                             'hour': 11},
#                            {'clear_sky': {'dhi': 126.75,
#                                           'dni': 950.69,
#                                           'ghi': 1007.84},
#                             'cloudy_sky': {'dhi': 368.52,
#                                            'dni': 49.91,
#                                            'ghi': 415.25},
#                             'hour': 12},
#                            {'clear_sky': {'dhi': 127.84,
#                                           'dni': 955.61,
#                                           'ghi': 1030.95},
#                             'cloudy_sky': {'dhi': 418.15,
#                                            'dni': 82.97,
#                                            'ghi': 497.38},
#                             'hour': 13},
#                            {'clear_sky': {'dhi': 125.08,
#                                           'dni': 943.51,
#                                           'ghi': 974.49},
#                             'cloudy_sky': {'dhi': 374.23,
#                                            'dni': 77.59,
#                                            'ghi': 444.83},
#                             'hour': 14},
#                            {'clear_sky': {'dhi': 118.25,
#                                           'dni': 912.0,
#                                           'ghi': 843.59},
#                             'cloudy_sky': {'dhi': 282.27,
#                                            'dni': 213.58,
#                                            'ghi': 453.7},
#                             'hour': 15},
#                            {'clear_sky': {'dhi': 106.68,
#                                           'dni': 853.68,
#                                           'ghi': 650.47},
#                             'cloudy_sky': {'dhi': 216.88,
#                                            'dni': 84.45,
#                                            'ghi': 271.21},
#                             'hour': 16},
#                            {'clear_sky': {'dhi': 88.76,
#                                           'dni': 749.42,
#                                           'ghi': 414.75},
#                             'cloudy_sky': {'dhi': 132.92,
#                                            'dni': 23.72,
#                                            'ghi': 143.41},
#                             'hour': 17},
#                            {'clear_sky': {'dhi': 59.86,
#                                           'dni': 536.36,
#                                           'ghi': 166.5},
#                             'cloudy_sky': {'dhi': 52.62,
#                                            'dni': 0.0,
#                                            'ghi': 52.62},
#                             'hour': 18},
#                            {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                             'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                             'hour': 19},
#                            {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                             'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                             'hour': 20},
#                            {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                             'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                             'hour': 21},
#                            {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                             'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                             'hour': 22},
#                            {'clear_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                             'cloudy_sky': {'dhi': 0.0, 'dni': 0.0, 'ghi': 0.0},
#                             'hour': 23}]},
#  'lat': 20.7337,
#  'lon': 116.8447,
#  'sunrise': '2023-03-30T06:08:08',
#  'sunset': '2023-03-30T18:26:39',
#  'tz': '+08:00'}

# %%
city_db.drop_collection('solar_c')
# Out:
# {'ok': 0.0,
#  'errmsg': 'ns not found',
#  'code': 26,
#  'codeName': 'NamespaceNotFound'}

# %%
solar_c.createCollection("noautoid", { autoIndexId: false })
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3472\864947971.py in <module>
# ----> 1 solar_c.createCollection("noautoid", { autoIndexId: false })
#
# NameError: name 'autoIndexId' is not defined
